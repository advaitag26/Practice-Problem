# %%
a = float(input("Enter your Marks:"))

if 100>= a >= 90:
    print("GRADE O") 
elif 89>= a >= 80:
    print("GRADE A+") 
elif 79>= a >= 70:
    print("GRADE A")
elif 69>= a >= 60:
    print("GRADE B")
elif 59>= a >= 50:
    print("GRADE C")
elif 49>= a >= 40:
    print("GRADE P")
else :
    print("GRADE F")
# Out:
# Enter your Marks: 93
# GRADE O

# %%
n = float(input("Enter the Number:"))
sum = 0
while n>0:
    digit = n%10
    sum  = sum + digit
    n= n//10

print("Sum of digit is:", sum)
# Out:
# Enter the Number: 56
# Sum of digit is: 11.0

# %%
n = int(input("Enter the number:"))
fact = 1
for i in range(1 , n+1):
    fact = fact * i
print("Factorial of the number: ", fact)
# Out:
# Enter the number: 6
# Factorial of the number:  720

# %%
x = int(input("Enter the number:"))
if x <=1:
    print("The number is not prime.")
else:
    prime = True
    for i in range(2, x):
        if x %i==0:
            prime= False
            break 
if prime:
    print("The is prime. ")
else:
    print("The number is not a prime.")
# Out:
# Enter the number: 6
# The number is not a prime.

# %%
for i in range(5):
    k = int(input("Enter the number:"))
    cube = k**3
    print("Cube:", cube)
# Out:
# Enter the number: 7889456512231265458798
# Cube: 491067576226675205818927917323426322001280786203434303953672865592
# Enter the number: 8928025511898331900897680107338928025511
# Cube: 711649695367227549672587634540607511934631744198085936485954078933538116560972551875365618138996996412763264457706507831
# Enter the number: 6
# Cube: 216
# Enter the number: 6
# Cube: 216
# Enter the number: 5
# Cube: 125

# %%
x = int(input("Enter the number:"))

reverse = 0
while x > 0:
    digit = x%10
    reverse =  reverse *10+ digit
    x = x//10
print("Reverse :", reverse)
# Out:
# Enter the number: 98
# Reverse : 89

# %%
year = int(input("Enter the YEAR:"))

if year % 400 == 0:
    print("The year the is a leap year")
elif year% 100 == 0:
    print("The year is not a leap year.")
elif year% 4 == 0:
    print("The year is a leap year.")
else:
    print("The year is not a leap year.")
# Out:
# Enter the YEAR: 2070
# The year is not a leap year.

# %%
number = [10,20,30,40,50]
print("List:",number)
print("First Number:",number[0])
print("Second Number:",number[1])
print("Third Number:",number[2])
print("Fourth Number:",number[3])
print("Fifth Number:",number[4])
# Out:
# List: [10, 20, 30, 40, 50]
# First Number: 10
# Second Number: 20
# Third Number: 30
# Fourth Number: 40
# Fifth Number: 50

# %%
Student_Name=str(input("Enter your Name:"))
Adress= str(input("Enter your Adress:"))
Contact_No= int(input("Enter your Contact Number:" ))
Mother_Tounge= str(input("Enter your Mother Tounge:"))
School_Name=str(input("Enter your School Name:"))
Year= int(input("Enter your Year:"))
Panel= str(input("Enter your Panel:"))
Roll_No= int(input("Enter your Roll Number:"))

print("Name:" , Student_Name)
print("Adress:" , Adress)
print("Contact Number:" , Contact_No)
print("Mother Tounge:" , Mother_Tounge)
print("School Name:" , School_Name)
print("Year:" , Year)
print("Panel:" , Panel)
print("Roll Number:" , Roll_No)
# Out:
# Enter your Name: dfgb
# Enter your School Name: wefg
# Enter your Year: 345
# Enter your Panel: dfbn
# Enter your Roll Number: 5243
# Name: dfgb
# Adress: wfgvbwf
# Contact Number: 2145
# Mother Tounge: fbergb
# School Name: wefg
# Year: 345
# Panel: dfbn
# Roll Number: 5243

# %%
Student_Name=str(input("Enter your Name:"))


Adress= str(input("Enter your Adress:"))
Contact_No= int(input("Enter your Contact Number:" ))
Mother_Tounge= str(input("Enter your Mother Tounge:"))
School_Name=str(input("Enter your School Name:"))
Year= int(input("Enter your Year:"))
Panel= str(input("Enter your Panel:"))
Roll_No= int(input("Enter your Roll Number:"))

print("Name:" , Student_Name)
print("Adress:" , Adress)
print("Contact Number:" , Contact_No)
print("Mother Tounge:" , Mother_Tounge)
print("School Name:" , School_Name)
print("Year:" , Year)
print("Panel:" , Panel)
print("Roll Number:" , Roll_No)
# Out:
# Enter your Name: fgjfgm
# Enter your Adress: fghmjgm
# Enter your Contact Number: 6564565656
# Enter your Mother Tounge: fgjhjfykij
# Enter your School Name: dghfgm
# Enter your Year: 4545
# Enter your Panel: drgdjh
# Enter your Roll Number: 65413123456456
# Name: fgjfgm
# Adress: fghmjgm
# Contact Number: 6564565656
# Mother Tounge: fgjhjfykij
# School Name: dghfgm
# Year: 4545
# Panel: drgdjh
# Roll Number: 65413123456456

# %%
name = str(input("Enter your Name:"))
p = float(input("Enter your Physics Marks"))
c = float(input("Enter your Chemistry Marks"))
m =float(input("Enter your Maths Marks"))

per = (p+c+m)/3

print("Total PCM percentage is" , per)

#For Gretest 
if m >= p and m>= c:
    if m == p:
        print("Maths and Physics has Greatest marks , with marks =", m)
    elif m==c:
        print("Maths and Chemistry has Greatest marks , with marks =", m)
    else:
        print("Maths has Greatest marks , with marks =", m)
elif p>= m and p>= c:
    if m == p:
        print("Physics and Maths has Greatest marks , with marks =", p)
    elif p==c:
        print("Physics and Chemistry has Greatest marks , with marks =", p)
    else:
        print("Physics has Greatest marks ,with marks =", p)
else :
    if c == p:
        print("Maths and Physics has Greatest marks , with marks =", c)
    elif c==m:
        print("Chemistry and Maths has Greatest marks , with marks =", c)
    else:
        print("Chemistry has Greatest marks, with marks =" , c)

#for Lowest
if m <= p and p<= c:
    if m == p:
        print("Maths and Physics has Lowest marks , with marks =", m)
    elif m==c:
        print("Maths and Chemistry has Lowest marks , with marks =", m)
    else:
        print("Maths has Lowest marks , with marks =", m)
elif p<= m and p<= c:
    if m == p:
        print("Physics and Maths has Lowest marks , with marks =", p)
    elif p==c:
        print("Physics and Chemistry has Lowest marks , with marks =", p)
    else:
        print("Physics has Lowest marks ,with marks =", p)
else :
     if c == p:
        print("Maths and Physics has Lowest marks , with marks =", c)
     elif c==m:
        print("Chemistry and Maths has Lowest marks , with marks =", c)
     else:
        print("Chemistry has Lowest marks, with marks =" , c)
# Out:
# Enter your Name: fhvbs
# Enter your Physics Marks 88
# Enter your Chemistry Marks 65
# Enter your Maths Marks 88
# Total PCM percentage is 80.33333333333333
# Maths and Physics has Greatest marks , with marks = 88.0
# Chemistry has Lowest marks, with marks = 65.0
